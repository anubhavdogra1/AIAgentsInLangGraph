# %% [markdown]
# # Lesson 4: Persistence and Streaming

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
tool = TavilySearchResults(max_results=2)

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %%
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-4o")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in sf?")]

# %%
thread = {"configurable": {"thread_id": "1"}}

# %%
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v['messages'])
# Out:
# [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz', 'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 151, 'total_tokens': 173, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-e2731928-d376-4a60-8a35-dd7e75de29a5-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}])]
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}
# Back to the model!
# [ToolMessage(content="HTTPError('500 Server Error: Internal Server Error for url: http://jupyter-api-proxy.internal.dlai/rev-proxy/tavily_search/search')", name='tavily_search_results_json', tool_call_id='call_bmfLa92f6oAIKN9KvXtqbKDz')]
# [AIMessage(content='I encountered an error while trying to retrieve the current weather in San Francisco. You might want to check a weather website or app like Weather.com or the Weather Channel for the most accurate and up-to-date information. If you have another query or need further assistance, feel free to ask!', response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 218, 'total_tokens': 276, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_ed643dde95', 'finish_reason': 'stop', 'logprobs': None}, id='run-ec8e46c0-adbc-4bbb-ade7-67f7d643f8ad-0')]

# %%
messages = [HumanMessage(content="What about in la?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_EvJvGDgTHkdY2T64ijcqKQ32', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 288, 'total_tokens': 310, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_689bad8e9a', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-11da6638-9b7e-4ab8-bf66-cbb7ab99e8dc-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_EvJvGDgTHkdY2T64ijcqKQ32'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_EvJvGDgTHkdY2T64ijcqKQ32'}
# Back to the model!
# {'messages': [ToolMessage(content="[{'url': 'https://www.weather25.com/south-america/chile/bio-bio/los-angeles?page=month&month=August', 'content': '| 30 Fog 14° /5° | 31 Overcast 15° /4° | [...] weather25.com \\n\\nUnited States England Australia Canada\\n\\n°F °C\\n\\nLos Angeles weather in Chile\\n\\nWeather in August 2026\\n\\nRemove from your favorite locations Add to my locations\\n\\nShare\\n\\n1. Home\\n2. South America\\n3. weather in ChileChile\\n4. Bio Bio\\n5. Los Angeles\\n6. August\\n\\nLocation was added to My Locations\\n\\nLocation was removed from My Locations\\n\\n# Los Angeles weather in August 2026\\n\\nClick on a day for an hourly weather forecast\\n\\nAug 11\\n\\nClear\\n\\n0 mm\\n\\n11° / -1°Aug 12\\n\\nSunny\\n\\n0 mm\\n\\n12° / -1°Aug 13\\n\\nPatchy rain possible\\n\\n1.3 mm\\n\\n13° / 2°Aug 14\\n\\nLight rain shower\\n\\n4.3 mm\\n\\n14° / 7°Saturday\\n\\nAug 15\\n\\nLight rain\\n\\n8.8 mm\\n\\n11° / 7°Sunday\\n\\nAug 16\\n\\nClear\\n\\n0 mm\\n\\n14° / 6°Monday\\n\\nAug 17\\n\\nClear\\n\\n0 mm\\n\\n14° / 4°Tuesday\\n\\nAug 18\\n\\nClear\\n\\n0 mm\\n\\n16° / 8°Wednesday\\n\\nAug 19\\n\\nOvercast\\n\\n0 mm\\n\\n15° / 6°Thursday\\n\\nAug 20 [...] Aug 19\\n\\nOvercast\\n\\n0 mm\\n\\n15° / 6°Thursday\\n\\nAug 20\\n\\nMist\\n\\n0 mm\\n\\n15° / 8°Friday\\n\\nAug 21\\n\\nModerate rain\\n\\n19 mm\\n\\n13° / 5°Saturday\\n\\nAug 22\\n\\nPatchy rain possible\\n\\n0.8 mm\\n\\n10° / 5°Sunday\\n\\nAug 23\\n\\nLight drizzle\\n\\n1.3 mm\\n\\n8° / 3°Monday\\n\\nAug 24\\n\\nSunny\\n\\n0 mm\\n\\n11° / 0° Next  \\nMonth >>\\n\\n## The average weather in Los Angeles in August\\n\\nThe temperatures in Los Angeles in August are quite cold with temperatures between 5°C and 13°C, warm clothes are a must.\\n\\nYou can expect rain for roughly half of the month of August in Los Angeles. We’re expecting roughly 8 to 15 days of rain, so your rubber boots and umbrella are going to see plenty of use this month if you’re keen on staying dry.\\n\\nOur weather forecast can give you a great sense of what weather to expect in Los Angeles in August 2026.'}, {'url': 'https://robinhood.com/us/en/prediction-markets/climate/events/los-angeles-daily-temperature-low-august-15-2026-aug-15-2026', 'content': 'Prediction markets / Climate / Daily Low Temperature\\n\\n# Los Angeles Daily Temperature Low August 15 2026\\n\\n<6987¢\\n\\n<6854¢\\n\\n<6717¢\\n\\nLIVE\\n\\n1D\\n\\n1W\\n\\nMAX\\n\\n## Select a contract\\n\\nLower than 70\\n\\n94¢\\n\\nLower than 69\\n\\n87¢\\n\\nLower than 68\\n\\n54¢\\n\\nLower than 67\\n\\n17¢\\n\\nLower than 66\\n\\n15¢\\n\\n## Timeline\\n\\nTrading hours\\n\\n24 hours a day, except Wednesday 3—3:15 AM ET\\n\\nEvent Day\\n\\nAugust 15, 2026\\n\\nContract Resolves\\n\\nDetermines the outcome of the contract\\n\\nPayout\\n\\nUsually within 1 hour of event resolution\\n\\n## About [...] What will the lowest temperature in Los Angeles be on August 15, 2026? The daily temperature low in Los Angeles, CA as reported by the Weather Underground for the Los Angeles Intl Airport Station (KLAX). This Contract resolves based solely on the final daily temperature values as displayed in the Summary data table described below for the applicable station and date once the first temperature observation for any subsequent calendar day has been published, indicating that all observations for the date specified in the Contract have been completed and made available through Weather Underground’s historical data display. Get $1 for every contract you own if your prediction is correct. Or close your position before the event resolves. Additional fees apply. Read the full contract terms and [...] Restrictions and eligibility requirements apply. Futures, options on futures and cleared swaps trading involves significant risk and is not appropriate for everyone. Please carefully consider if it is appropriate for you in light of your personal financial circumstances.\\n\\nRead the Event Contracts Risk Disclosure for more information about the risks  ...
# {'messages': [AIMessage(content='I encountered an issue retrieving the current weather in Los Angeles. You can check real-time weather updates on reliable sites like Weather.com or the Weather Channel. If you need further assistance or have another question, feel free to ask!', response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 1446, 'total_tokens': 1492, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_684acb85fd', 'finish_reason': 'stop', 'logprobs': None}, id='run-5550fc16-bb82-4d9b-9fb8-316cda602e70-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_3DODZUAmeT427IB0jKGnmb5g', 'function': {'arguments': '{"query": "current temperature in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_AbPD3ehVAAjoEMp2hVvQhHk2', 'function': {'arguments': '{"query": "current temperature in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 1504, 'total_tokens': 1564, 'prompt_tokens_details': {'cached_tokens': 1408, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_684acb85fd', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-283cbe52-ca98-4e0d-9a85-d24140b36c1b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in San Francisco'}, 'id': 'call_3DODZUAmeT427IB0jKGnmb5g'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in Los Angeles'}, 'id': 'call_AbPD3ehVAAjoEMp2hVvQhHk2'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in San Francisco'}, 'id': 'call_3DODZUAmeT427IB0jKGnmb5g'}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in Los Angeles'}, 'id': 'call_AbPD3ehVAAjoEMp2hVvQhHk2'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.wunderground.com/weather/us/ca/san-francisco\', \'content\': "Location: San Francisco, CA\\n\\nElevation: 39ft\\n\\nNearby Weather Stations\\n\\nNo PWS\\n\\nReset Map, or Add PWS.\\n\\nzoom out;)\\n\\nShowing Stations\\n\\naccess\\\\_time 2:07 PM PDT on August 14, 2026 (GMT -7) | Updated 8 seconds ago\\n\\n69° | 59°\\n\\n67 °F\\n\\nlike 67°\\n\\nicon\\n\\nCloudy\\n\\nN\\n\\n1\\n\\nGusts 6 °mph\\n\\nToday\'s temperature is forecast to be WARMER than yesterday.\\n\\n Radar\\n Satellite\\n\\nWunderMap|Nexrad\\n\\nicon\\n\\nTodayFri 08/14 High 69 °F\\n\\n2% Precip. / 0.00 °in  \\nMostly cloudy. High 69F. Winds W at 10 to 20 mph.\\n\\nicon\\n\\nTonightFri 08/14 Low 59 °F\\n\\n24% Precip. / 0.00 °in  \\nCloudy. Low 59F. Winds W at 10 to 20 mph.\\n\\nicon\\n\\nTomorrowSat 08/15 High 68 °F | 57 °F\\n\\n21% Precip. / 0.00 °in  \\nCloudy. High 68F. Winds W at 10 to 20 mph.\\n\\nTop Video Stories\\n\\n keyboard\\\\_arrow\\\\_left\\n keyboard\\\\_arrow\\\\_right\\n\\nSee more Top Video Stories [...] Skip to Main Content \\\\_ \\n\\nclosegps\\\\_fixed\\n\\n gps\\\\_fixedFind Nearest Station\\n Manage Favorite Cities\\n\\nLog In\\n\\naccount\\\\_box Log in settings SettingsSensor NetworkMaps & RadarSevere WeatherNews & BlogsMobile AppsHistorical Weather\\n\\nclosegps\\\\_fixed\\n\\n gps\\\\_fixedFind Nearest Station\\n Manage Favorite Cities\\n\\nElev 39 ft, 37.78 °N, 122.42 °W \\n\\n# San Francisco, CA Weather Conditionsstar\\\\_ratehome\\n\\nicon67 °F South of Market Station|Report\\n\\nReport Station\\n\\nThank you for reporting this station. We will review the data in question.\\n\\nYou are about to report this weather station for bad data. Please select the information that is incorrect.\\n\\n|Change\\n\\nSee more\\n\\n(Reset Map)\\n\\nCurrent Station\\n\\nPersonal Weather Station\\n\\nSouth of Market (KCASANFR1753)\\n\\nLocation: San Francisco, CA\\n\\nElevation: 39ft [...] See more Top Video Stories\\n\\nAdditional Conditions\\n\\nPressure\\n\\n30.03 °in\\n\\nVisibility\\n\\n8 °miles\\n\\nClouds\\n\\nCloudy\\n\\nDew Point\\n\\n57 °F\\n\\nHumidity\\n\\n58 °%\\n\\nRainfall\\n\\n0 °in\\n\\nSnow Depth\\n\\n0 °in\\n\\nTop Video Stories\\n\\n keyboard\\\\_arrow\\\\_left\\n keyboard\\\\_arrow\\\\_right\\n\\nSee more Top Video Stories\\n\\nAstronomy\\n\\nSun\\n\\nRise\\n\\nSet\\n\\nActual Time\\n\\n6:25 AM\\n\\n8:05 PM\\n\\nCivil Twilight\\n\\n5:57 AM\\n\\n8:33 PM\\n\\nNautical Twilight\\n\\n5:23 AM\\n\\n9:07 PM\\n\\nAstronomical Twilight\\n\\n4:47 AM\\n\\n9:43 PM\\n\\nLength of Visible Light\\n\\n14 h 36 m\\n\\nLength of Day\\n\\n13 h 40 m\\n\\nTomorrow will be 2 minutes 6 seconds shorter\\n\\nMoon\\n\\n8:37 AM\\n\\n9:11 PM\\n\\nicon\\n\\nwaxing crescent\\n\\n6% of the Moon is Illuminated\\n\\nicon\\n\\nAug 20\\n\\nWaxing Half First Qtr\\n\\nicon\\n\\nAug 28\\n\\nFull Moon\\n\\nicon\\n\\nSep 4\\n\\nWaning Half Last Qtr\\n\\nicon\\n\\nSep 11\\n\\nNew Moon"}, {\'url\': \'https://www.theweathernetwork.com/en/city/us/california/san-francisco/current\', \'content\': "|\\n\\n# San Francisco, CA Current Weather\\n\\nSan Francisco, CA\\n\\nUpdated11 minutes ago\\n\\n°C\\n\\nOvercast\\n\\nFeels13\\n\\nH:16°   L:14°\\n\\n## Hourly\\n\\nFull 72 hours\\n\\n10am\\n\\nMainly cloudy\\n\\n15°\\n\\nFeels 14\\n\\nPOP\\n\\n30%\\n\\n11am\\n\\nCloudy with sunny breaks\\n\\n15°\\n\\nFeels 15\\n\\nPOP\\n\\n20%\\n\\n12pm\\n\\nA mix of sun and clouds\\n\\n16°\\n\\nFeels 15\\n\\nPOP\\n\\n20%\\n\\n1pm\\n\\nA mix of sun and clouds\\n\\n16°\\n\\nFeels 15\\n\\nPOP\\n\\n20%\\n\\n2pm\\n\\nA mix of sun and clouds\\n\\n16°\\n\\nFeels 15\\n\\nPOP\\n\\n20%\\n\\nPeeks of sun for the next 6 hours, then partly cloudy after 4pm.\\n\\n## Today’s Conditions\\n\\n --\\n\\n  Sunrise\\n\\n  --\\n\\n  Sunset\\n\\n  --\\n\\n  No Data Available\\n Wind\\n\\n  --\\n\\n  Gust:\\n\\n  --\\n\\n  No Data Available\\n Pressure\\n\\n  --\\n\\n  No Data Available\\n Humidity\\n\\n  --\\n\\n  No Data Available\\n Visibility\\n\\n  --\\n\ ...
# {'messages': [AIMessage(content="I was able to retrieve the current temperature for San Francisco, but encountered an error for Los Angeles. Here's what I found:\n\n- **San Francisco**: The current temperature is around 67°F (approximately 19°C), with mostly cloudy conditions.\n\nFor Los Angeles, you might want to check a reliable weather website like Weather.com for the latest information. If you need further assistance or have another question, feel free to ask!", response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 3813, 'total_tokens': 3900, 'prompt_tokens_details': {'cached_tokens': 1408, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_684acb85fd', 'finish_reason': 'stop', 'logprobs': None}, id='run-115901ba-fb9d-4c7d-8e2f-af8e8c110e50-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Could you please clarify what you're comparing to determine which is warmer? Are you comparing two specific locations, types of clothing, materials, or something else? Let me know so I can provide the appropriate information.", response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 149, 'total_tokens': 192, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None}, id='run-cac69a82-8770-4a94-b801-f7ddd07cce2d-0')]}

# %% [markdown]
# ## Streaming tokens

# %%
from langgraph.checkpoint.aiosqlite import AsyncSqliteSaver

memory = AsyncSqliteSaver.from_conn_string(":memory:")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in SF?")]
thread = {"configurable": {"thread_id": "4"}}
async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
# Out:
# /usr/local/lib/python3.11/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: This API is in beta and may change in the future.
#   warn_beta(
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_GiHnpbt7P6kuX4g2n6imqDXI'}
# Back to the model!
# I| encountered| an| error| while| trying| to| retrieve| the| current| weather| information| for| San| Francisco|.| You| might| want| to| check| a| reliable| weather| website| or| app| for| the| most| up|-to|-date| information|.| If| there's| anything| else| you'd| like| to| know| or| another| way| I| can| assist| you|,| please| let| me| know|!|
